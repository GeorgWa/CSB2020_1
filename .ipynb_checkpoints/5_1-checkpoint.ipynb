# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

# %% [markdown]
# $N$ Population size<br>
# $S(t)$ Susceptible people<br>
# $E_1(t), E_2(t), E_3(t)$ Incubation states between infection and infectiousness<br>
# $R(t)$ Recovered Patients
#
# $t_i$ average time between onset of sickness and recovery / death<br>
# $t_l$ latency time between infection and infectiousness<br>
# $R_0$ Average number of transmissions during the course of infection
#
# $\beta = \frac{R_0}{t_i}$ Infection rate
#
#
# $$
# \begin{align*}
#     \frac{dS}{dt} &= -\beta S(t) I(t) N^{-1}\\
#     \frac{dE_1}{dt} &= \beta S(t) I(t) N^{-1} - 3 E_1(t) t_l^{-1}\\
#     \frac{dE_2}{dt} &= 3 E_1(t) t_l^{-1} - 3 E_2(t) t_l^{-1}\\
#     \frac{dE_3}{dt} &= 3 E_2(t) t_l^{-1} - 3 E_3(t) t_l^{-1}\\
#     \frac{dI}{dt} &= 3 E_3(t) t_l^{-1} - I(t) t_i^{-1} \\
#     \frac{dR}{dt} &= I(t) t_i^{-1} \\
# \end{align*}
# $$

# %%
def system(v,t):
    N = 1000
    tl = 3
    ti = 5
    beta = 2/ti
    
    S, E1, E2, E3, I, R = v
    dvdt = [
        -beta*S*I/N, 
        beta*S*I/N - 3*E1/tl,
        3*E1/tl - 3*E2/tl,
        3*E2/tl - 3*E3/tl,
        3*E3/tl - I/ti,
        I/ti]
    return dvdt

# %%
t = np.linspace(0,100,200)

v0 = [980,0,0,0,20,0]

solution = odeint(system, v0, t)

plt.plot(t,solution[:,0], label=r"Susceptible")
plt.plot(t,solution[:,4], label=r"Infected")
plt.plot(t,solution[:,5], label=r"Recovered")

plt.title("cumulative groups")
plt.xlabel("t in days")
plt.legend(loc='best')
